# %% [markdown]
# <a href="https://colab.research.google.com/github/orestes7054/acme/blob/main/chatBotWA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import string
import random
import nltk
import numpy as num
from nltk.stem import WordNetLemmatizer # It has the ability to lemmatize.
import tensorflow as tensorF # A multidimensional array of elements is represented by this symbol.
from tensorflow.keras import Sequential # Sequential groups a linear stack of layers into a tf.keras.Model
from tensorflow.keras.layers import Dense, Dropout

nltk.download("punkt")# required package for tokenization
nltk.download("wordnet")# word database
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
data = {"intents": [

             {"tag": "age",
              "patterns": ["how old are you?"],
              "responses": ["I am 2 years old and my birthday was yesterday"]
             },
              {"tag": "greeting",
              "patterns": [ "Hi", "Hello", "Hey"],
              "responses": ["Hi there", "Hello", "Hi :)"],
             },
              {"tag": "goodbye",
              "patterns": [ "bye", "later"],
              "responses": ["Bye", "take care"]
             },
             {"tag": "name",
              "patterns": ["what's your name?", "who are you?"],
              "responses": ["I have no name yet," "You can give me one, and I will appreciate it"]
             }

]}

# %%
lm = WordNetLemmatizer() #for getting words
# lists
ourClasses = []
newWords = []
documentX = []
documentY = []
# Each intent is tokenized into words and the patterns and their associated tags are added to their respective lists.
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        ournewTkns = nltk.word_tokenize(pattern)# tokenize the patterns
        newWords.extend(ournewTkns)# extends the tokens
        documentX.append(pattern)
        documentY.append(intent["tag"])


    if intent["tag"] not in ourClasses:# add unexisting tags to their respective classes
        ourClasses.append(intent["tag"])

newWords = [lm.lemmatize(word.lower()) for word in newWords if word not in string.punctuation] # set words to lowercase if not in punctuation
newWords = sorted(set(newWords))# sorting words
ourClasses = sorted(set(ourClasses))# sorting classes

# %%
trainingData = [] # training list array
outEmpty = [0] * len(ourClasses)
# bow model
for idx, doc in enumerate(documentX):
    bagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in newWords:
        bagOfwords.append(1) if word in text else bagOfwords.append(0)

    outputRow = list(outEmpty)
    outputRow[ourClasses.index(documentY[idx])] = 1
    trainingData.append([bagOfwords, outputRow])

random.shuffle(trainingData)
trainingData = num.array(trainingData, dtype=object)# coverting our data into an array afterv shuffling

x = num.array(list(trainingData[:, 0]))# first trainig phase
y = num.array(list(trainingData[:, 1]))# second training phase

# %%
iShape = (len(x[0]),)
oShape = len(y[0])
# parameter definition
ourNewModel = Sequential()
# In the case of a simple stack of layers, a Sequential model is appropriate

# Dense function adds an output layer
ourNewModel.add(Dense(128, input_shape=iShape, activation="relu"))
# The activation function in a neural network is in charge of converting the node's summed weighted input into activation of the node or output for the input in question
ourNewModel.add(Dropout(0.5))
# Dropout is used to enhance visual perception of input neurons
ourNewModel.add(Dense(64, activation="relu"))
ourNewModel.add(Dropout(0.3))
ourNewModel.add(Dense(oShape, activation = "softmax"))
# below is a callable that returns the value to be used with no arguments
md = tensorF.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
# Below line improves the numerical stability and pushes the computation of the probability distribution into the categorical crossentropy loss function.
ourNewModel.compile(loss='categorical_crossentropy',
              optimizer=md,
              metrics=["accuracy"])
# Output the model in summary
print(ourNewModel.summary())
# Whilst training your Nural Network, you have the option of making the output verbose or simple.
ourNewModel.fit(x, y, epochs=200, verbose=1)
# By epochs, we mean the number of times you repeat a training set.
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1920
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 10,436
# Trainable params: 10,436
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 1s 764ms/step - loss: 1.3788 - accuracy: 0.2500
# Epoch 2/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2870 - accuracy: 0.6250
# Epoch 3/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2629 - accuracy: 0.6250
# Epoch 4/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0865 - accuracy: 0.8750
# Epoch 5/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9174 - accuracy: 0.8750
# Epoch 6/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.8817 - accuracy: 1.0000
# Epoch 7/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7548 - accuracy: 0.8750
# Epoch 8/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6682 - accuracy: 1.0000
# Epoch 9/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6706 - accuracy: 1.0000
# Epoch 10/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5310 - accuracy: 1.0000
# Epoch 11/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4799 - accuracy: 0.8750
# Epoch 12/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.5227 - accuracy: 0.8750
# Epoch 13/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3224 - accuracy: 0.8750
# Epoch 14/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2043 - accuracy: 1.0000
# Epoch 15/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1952 - accuracy: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1193 - accuracy: 1.0000
# Epoch 17/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1070 - accuracy: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0983 - accuracy: 1.0000
# Epoch 19/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0542 - accuracy: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 21/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 22/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.3016e-04 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.5687e-04 - accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.6950e-04 - accuracy: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 9ms/step - loss: 6.1468e-04 - accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5615e-04 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 8ms/step - loss: 9.2361e-05 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.1242e-04 - accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 10ms/step - loss: 8.0949e-05 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 9ms/step - loss: 6.0701e-05 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.8138e-05 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 15ms/step - loss: 5.2936e-04 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4599e-04 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1101e-05 - accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7689e-04 - accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5005e-05 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5553e-04 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.0376e-04 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.8114e-06 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.6640e-06 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.3677e-05 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4558e-05 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.5415e-05 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3142e-05 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.4675e-04 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 9ms/step - loss: 4.6069e-05 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 8ms/step - loss: 9.2616e-04 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3793e-06 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.0464e-06 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.6825e-04 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.2763e-05 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.2286e-06 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.0554e-05 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 10ms/step - loss: 7.3928e-04 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.1367e-05 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.6127e-04 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.2330e-05 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0378e-04 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.8444e-04 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8356e-05 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.5259e-04 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4254e-04 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.0508e-04 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.0816e-05 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1488e-05 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7061e-05 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.9234e-04 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 7ms/step - loss: 7.1047e-04 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5034e-06 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1004e-04 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.4609e-04 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.4097e-04 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.7865e-06 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.1061e-06 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1891e-05 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.9475e-05 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.5785e-05 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9485e-04 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.5565e-07 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 7ms/step - loss: 5.8888e-04 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.7957e-04 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.9117e-05 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.6964e-04 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7055e-07 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0535e-05 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.0637e-05 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1308e-06 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 7ms/step - loss: 3.3123e-05 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2487e-05 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 7ms/step - loss: 8.4837e-04 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1489e-05 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 7ms/step - loss: 3.4062e-05 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 7ms/step - loss: 8.4999e-05 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3858e-05 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 7ms/step - loss: 6.1025e-04 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5765e-05 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.6314e-05 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 8ms/step - loss: 7.2333e-04 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.0081e-04 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 7ms/step - loss: 4.0043e-04 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0029e-04 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.7010e-04 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 7ms/step - loss: 3.1640e-04 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0726e-05 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5854e-04 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 7ms/step - loss: 7.4653e-06 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3172e-05 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 7ms/step - loss: 9.1490e-05 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 7ms/step - loss: 7.5996e-06 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 7ms/step - loss: 3.0203e-05 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2799e-05 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 7ms/step - loss: 7.8676e-06 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 7ms/step - loss: 6.0946e-05 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0640e-05 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 7ms/step - loss: 3.3378e-06 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.3763e-05 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.7002e-04 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.5532e-05 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.6943e-04 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.1159e-06 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3411e-05 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 8ms/step - loss: 9.1655e-05 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5497e-05 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 9ms/step - loss: 6.4968e-06 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.2505e-05 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 9ms/step - loss: 4.6828e-05 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 9ms/step - loss: 7.3557e-04 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3834e-04 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 9ms/step - loss: 3.5763e-07 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.6027e-06 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 9ms/step - loss: 7.5238e-05 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.1011e-06 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.7178e-05 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.4736e-06 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.0862e-07 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.4733e-05 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7359e-05 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.1300e-05 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 8ms/step - loss: 9.1345e-05 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1220e-05 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.4393e-05 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4945e-05 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.6207e-05 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 8ms/step - loss: 7.6144e-06 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 7ms/step - loss: 6.9736e-06 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 14ms/step - loss: 4.0531e-06 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.9935e-05 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 7ms/step - loss: 3.0248e-05 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 15ms/step - loss: 3.8743e-06 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2236e-05 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.0774e-05 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1027e-05 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5286e-05 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.4422e-06 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9222e-06 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4217e-04 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 7ms/step - loss: 3.3986e-05 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 7ms/step - loss: 4.7278e-05 - accuracy: 1.0000

# %%
def ourText(text):
  newtkns = nltk.word_tokenize(text)
  newtkns = [lm.lemmatize(word) for word in newtkns]
  return newtkns

def wordBag(text, vocab):
  newtkns = ourText(text)
  bagOwords = [0] * len(vocab)
  for w in newtkns:
    for idx, word in enumerate(vocab):
      if word == w:
        bagOwords[idx] = 1
  return num.array(bagOwords)

def Pclass(text, vocab, labels):
  bagOwords = wordBag(text, vocab)
  ourResult = ourNewModel.predict(num.array([bagOwords]))[0]
  newThresh = 0.2
  yp = [[idx, res] for idx, res in enumerate(ourResult) if res > newThresh]

  yp.sort(key=lambda x: x[1], reverse=True)
  newList = []
  for r in yp:
    newList.append(labels[r[0]])
  return newList

def getRes(firstlist, fJson):
  tag = firstlist[0]
  listOfIntents = fJson["intents"]
  for i in listOfIntents:
    if i["tag"] == tag:
      ourResult = random.choice(i["responses"])
      break
  return ourResult

# %%
while True:
    newMessage = input("")
    intents = Pclass(newMessage, newWords, ourClasses)
    ourResult = getRes(intents, data)
    print(ourResult)
# Out:
# name?
# 1/1 [==============================] - 0s 80ms/step
# I have no name yet,You can give me one, and I will appreciate it
# years old?
# 1/1 [==============================] - 0s 22ms/step
# I am 2 years old and my birthday was yesterday
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-965d35fd14ab> in <module>
#       1 while True:
# ----> 2     newMessage = input("")
#       3     intents = Pclass(newMessage, newWords, ourClasses)
#       4     ourResult = getRes(intents, data)
#       5     print(ourResult)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
